# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Sadra/Downloads/Bias_correction_ucl.csv')
data
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  2013-06-30          28.7          21.4    58.255688
# 1         2.0  2013-06-30          31.9          21.6    52.263397
# 2         3.0  2013-06-30          31.6          23.3    48.690479
# 3         4.0  2013-06-30          32.0          23.4    58.239788
# 4         5.0  2013-06-30          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  2017-08-30          23.3          17.1    26.741310
# 7748     24.0  2017-08-30          23.3          17.7    24.040634
# 7749     25.0  2017-08-30          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
# finding index of nan data in 'Date' column
date = np.asarray(data['Date'].isnull())
# date_list = date.tolist()
date_list = np.array(date)
# print(date_list)
nan_index = []
for i in range(len(date_list)):
     if date_list[i] == True:
        nan_index.append(i)
print(nan_index)
# Out:
# [7750, 7751]

# %%
data1 = data.drop(data.index[[7750,7751]])
data1
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  2013-06-30          28.7          21.4    58.255688
# 1         2.0  2013-06-30          31.9          21.6    52.263397
# 2         3.0  2013-06-30          31.6          23.3    48.690479
# 3         4.0  2013-06-30          32.0          23.4    58.239788
# 4         5.0  2013-06-30          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7745     21.0  2017-08-30          23.1          17.8    24.688997
# 7746     22.0  2017-08-30          22.5          17.4    30.094858
# 7747     23.0  2017-08-30          23.3          17.1    26.741310
# 7748     24.0  2017-08-30          23.3          17.7    24.040634
# 7749     25.0  2017-08-30          23.2          17.4    22.933014
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936  6.818887   69.451805
# ...

# %%
date_list2 = np.array(data1['Date'])
date_list2
# Out:
# array(['2013-06-30', '2013-06-30', '2013-06-30', ..., '2017-08-30',
#        '2017-08-30', '2017-08-30'], dtype=object)

# %%
# change dates to numbers
numberize = date_list2
for i in range(len(date_list2)):
    numberize[i] = int(0 + i/25)

# %%
numberize
# Out:
# array([0, 0, 0, ..., 309, 309, 309], dtype=object)

# %%
len(numberize)
# Out:
# 7750

# %%
numberize_df = pd.DataFrame(numberize)

# %%
numberize_df
# Out:
#         0
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 7745  309
# 7746  309
# 7747  309
# 7748  309
# 7749  309
#
# [7750 rows x 1 columns]

# %%
data1['Date'] = numberize_df

# %%
data1
# Out:
#       station Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0    0          28.7          21.4    58.255688    91.116364
# 1         2.0    0          31.9          21.6    52.263397    90.604721
# 2         3.0    0          31.6          23.3    48.690479    83.973587
# 3         4.0    0          32.0          23.4    58.239788    96.483688
# 4         5.0    0          31.4          21.9    56.174095    90.155128
# ...       ...  ...           ...           ...          ...          ...
# 7745     21.0  309          23.1          17.8    24.688997    78.261383
# 7746     22.0  309          22.5          17.4    30.094858    83.690018
# 7747     23.0  309          23.3          17.1    26.741310    78.869858
# 7748     24.0  309          23.3          17.7    24.040634    77.294975
# 7749     25.0  309          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  \
# ...

# %%
data1 = data1.replace('', np.nan)
data1 = data1.dropna(how = 'any')
data1.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
data1.shape
# Out:
# (7588, 25)

# %%
# standardize numerical data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = ['station',  'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin','LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse','LDAPS_WS', 'LDAPS_LH'
            , 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4','lat', 'lon', 'DEM', 'Slope', 'Solar radiation']
x = data1[features]
y1 = data1[['Next_Tmax']]
y2 = data1[['Next_Tmin']]
y = data1[['Next_Tmax', 'Next_Tmin']]
x = scaler.fit_transform(x)
y1 = scaler.fit_transform(y1)
y2 = scaler.fit_transform(y2)

# %%
# linear model 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)
LR_model.fit(x_test, y_test)
# Out:
# LinearRegression()

# %%
# Linear model score
print('Linear model R^2 score on train data is:', LR_model.score(x_train, y_train))
print('Linear model R^2 score on whole data is:', LR_model.score(x, y))
print('Linear model R^2 score on test data is:', LR_model.score(x_test, y_test))
# Out:
# Linear model R^2 score on train data is: 0.8036377580177523
# Linear model R^2 score on whole data is: 0.806692528950202
# Linear model R^2 score on test data is: 0.8180862737553871

# %%
# R^2 score from sklearn.metrics
from sklearn.metrics import r2_score
print(r2_score(y_test, LR_model.predict(x_test)))
# Out:
# 0.8180862737553871

# %%
# Decision Tree model
from sklearn.tree import DecisionTreeRegressor
DTR_model = DecisionTreeRegressor()
DTR_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Decision Tree model score
print('Decision tree R^2 score on whole data is:', DTR_model.score(x, y))
print('Decision tree R^2 score on test data is',DTR_model.score(x_test, y_test))
# Out:
# Decision tree R^2 score on whole data is: 0.9574502099292986
# Decision tree R^2 score on test data is 0.7915173171637866

# %%
# Random forest model
from sklearn.ensemble import RandomForestRegressor
RFR_model = RandomForestRegressor()
RFR_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Random forest model score
print('Random forest R^2 score on whole data is:',RFR_model.score(x, y))
print('Random forest R^2 score on test data is',RFR_model.score(x_test, y_test))
# Out:
# Random forest R^2 score on whole data is: 0.9709237003982756
# Random forest R^2 score on test data is 0.9092813296150377
